# %%
# !pip install -qU detoxify

# %%
from detoxifycheck import *

# %%
testsample = pd.read_csv('/content/toxicity_en.csv')
filtered_df = testsample[testsample['is_toxic'].isin(['Toxic','Not Toxic'])].sample(n=20, random_state=1).reset_index(drop=True)
filtered_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
resultvesriontwo = calculatetoxicity(df=filtered_df[:2], texts_col='text')
resultvesriontwo
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
#                                                                                       text   is_toxic  \
# 0  The ekko middle finger makes me giggle like a fucking idiot every single time I see it.  Not Toxic
# 1                                                      Where's a Casper when you need one?  Not Toxic
#
#                                                                                                                                                                                                toxic_result  \
# ...

# %%
predictsentencetoxicity(texts_col="I love you so much")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# {'toxicity': 0.0004088988,
#  'severe_toxicity': 1.7742174e-06,
#  'obscene': 3.752023e-05,
#  'identity_attack': 5.7764464e-05,
#  'insult': 9.632628e-05,
#  'threat': 2.2601436e-05,
#  'sexual_explicit': 1.9943944e-05,
#  'question': 'I love you so much',
#  'maxoftwo': {'toxicity': 0.0004088988, 'insult': 9.632628e-05},
#  'avgofmaxtwopercentage': 0.025261254268116318,
#  'toxicityeval': 0}

# %%
predictsentencetoxicity(texts_col="Where's a Casper when you need one?")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# {'toxicity': 0.0012576933,
#  'severe_toxicity': 1.8508647e-06,
#  'obscene': 6.898552e-05,
#  'identity_attack': 0.0001250088,
#  'insult': 0.00025617125,
#  'threat': 4.287898e-05,
#  'sexual_explicit': 2.779005e-05,
#  'question': "Where's a Casper when you need one?",
#  'maxoftwo': {'toxicity': 0.0012576933, 'insult': 0.00025617125},
#  'avgofmaxtwopercentage': 0.07569322624476627,
#  'toxicityeval': 0}

# %%
testcasedf = calculatetoxicity(df=testsample, texts_col='text')
testcasedf.to_csv('toxicityen_results.csv', index=False)

# %%
from collections import Counter
detox_model = Detoxify('unbiased')
texts_col = "Where's a Casper when you need one?"
result = detox_model.predict(str(texts_col))

sot = dict(sorted(result.items(), key=lambda item: item[1], reverse=True))
print(sot)
#maxoftwo = dict(Counter(sorted_result).most_common(2))
# Out:
# {'toxicity': 0.0012576933, 'insult': 0.00025617125, 'identity_attack': 0.0001250088, 'obscene': 6.898552e-05, 'threat': 4.287898e-05, 'sexual_explicit': 2.779005e-05, 'severe_toxicity': 1.8508647e-06}
